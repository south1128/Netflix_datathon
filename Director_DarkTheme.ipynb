# %%
# !pip install kaggle --upgrade
#!pip install -U kaleido  # plotly 그래프를 github에서 이미지로 보여주기 위해서

import os
os.environ['KAGGLE_USERNAME'] = 'hardm00n'
os.environ['KAGGLE_KEY'] = '705411ac0f42b6a6e137b07cfb0b188e'

# !kaggle datasets download -d shivamb/netflix-shows
# !unzip '*.zip'
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.10.8)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (6.1.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.63.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Downloading netflix-shows.zip to /content
#   0% 0.00/1.34M [00:00<?, ?B/s]
# 100% 1.34M/1.34M [00:00<00:00, 58.4MB/s]
# Archive:  netflix-shows.zip
#   inflating: netflix_titles.csv

# %%
# !ls
# Out:
# netflix-shows.zip  netflix_titles.csv  sample_data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# plotly : 시각화 라이브러리, 그래프가 타 라이브러리에 비해 아름답다.
import plotly.offline as py 
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls

import warnings
warnings.filterwarnings('ignore')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data = pd.read_csv('/content/netflix_titles.csv')
print(data.shape)
data.head()
# Out:
# (8807, 12)
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
data['country'] = data['country'].fillna(data['country'].mode()[0])  # 최빈값으로 결측치 대체
#data['director'].replace(np.nan, 'No Data', inplace=True)  # 감독 결측치는 'No Data'로 일단은 대체 -> 결측치 제거로 변경!
data.dropna(inplace=True) # 기타 결측치 제거
data.head()
# Out:
#   show_id     type                             title  \
# 2      s3  TV Show                         Ganglands
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
#
#                         director  \
# 2                Julien Leclercq
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
#
#                                                 cast  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country          date_added  \
# 2                                      United States  September 24, 2021
# 5                                      United States  September 24, 2021
# 6                                      United States  September 24, 2021
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
#
#    release_year rating   duration  \
# 2          2021  TV-MA   1 Season
# 5          2021  TV-MA   1 Season
# 6          2021     PG     91 min
# 7          1993  TV-MA    125 min
# 8          2021  TV-14  9 Seasons
#
#                                            listed_in  \
# 2  Crime TV Shows, International TV Shows, TV Act...
# 5                 TV Dramas, TV Horror, TV Mysteries
# 6                           Children & Family Movies
# 7   Dramas, Independent Movies, International Movies
# 8                       British TV Shows, Reality TV
#
#                                          description
# 2  To protect his family from a powerful drug lor...
# 5  The arrival of a charismatic young priest brin...
# 6  Equestria's divided. But a bright-eyed hero be...
# 7  On a photo shoot in Ghana, an American model s...
# 8  A talented batch of amateur bakers face off in...

# %%
import datetime

data['date_added'] = pd.to_datetime(data['date_added'])
data['month'] = data['date_added'].dt.month

# %%
data['season'] = 0
data.loc[(data['month'] < 3) | (data['month'] == 12), 'season'] = 'Winter'
data.loc[(data['month'] >= 3) & (data['month'] < 6), 'season'] = 'Spring'
data.loc[(data['month'] >= 6) & (data['month'] < 9), 'season'] = 'Summer'
data.loc[(data['month'] >= 9) & (data['month'] < 12), 'season'] = 'Autumn'
data = data.drop(['date_added', 'month', 'cast', 'description'], axis=1)

# %%
data
# Out:
#      show_id     type                             title  \
# 2         s3  TV Show                         Ganglands
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# 7         s8    Movie                           Sankofa
# 8         s9  TV Show     The Great British Baking Show
# ...      ...      ...                               ...
# 8801   s8802    Movie                           Zinzana
# 8802   s8803    Movie                            Zodiac
# 8804   s8805    Movie                        Zombieland
# 8805   s8806    Movie                              Zoom
# 8806   s8807    Movie                            Zubaan
#
#                            director  \
# 2                   Julien Leclercq
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 8                   Andy Devonshire
# ...                             ...
# 8801                Majid Al Ansari
# 8802                  David Fincher
# 8804                Ruben Fleischer
# 8805                   Peter Hewitt
# 8806                    Mozez Singh
#
#                                                 country  release_year rating  \
# 2                                         United States          2021  TV-MA
# 5                                         United States          2021  TV-MA
# 6                                         United States          2021     PG
# 7     United States, Ghana, Burkina Faso, United Kin...          1993  TV-MA
# 8                                        United Kingdom          2021  TV-14
# ...                                                 ...           ...    ...
# 8801                       United Arab Emirates, Jordan          2015  TV-MA
# 8802                                      United States          2007      R
# 8804                                      United States          2009      R
# 8805                                      United States          2006     PG
# 8806                                              India          2015  TV-14
#
#        duration                                          listed_in  season
# 2      1 Season  Crime TV Shows, International TV Shows, TV Act...  Autumn
# 5      1 Season                 TV Dramas, TV Horror, TV Mysteries  Autumn
# 6        91 min                           Children & Family Movies  Autumn
# 7       125 min   Dramas, Independent Movies, International Movies  Autumn
# 8     9 Seasons                       British TV Shows, Reality TV  Autumn
# ...         ...                                                ...     ...
# 8801     96 min            Dramas, International Movies, Thrillers  Spring
# 8802    158 min                     Cult Movies, Dramas, Thrillers  Autumn
# 8804     88 min                            Comedies, Horror Movies  Autumn
# 8805     88 min                 Children & Family Movies, Comedies  Winter
# 8806    111 min     Dramas, International Movies, Music & Musicals  Spring
#
# [5696 rows x 10 columns]

# %% [markdown]
# ## 계절별 director 분석
#
# - `date_added`의 month를 기준으로 4계절을 나누었고, 계절별로 데이터셋의 각 컬럼별 상관 관계를 알아보고자 한다.
# - 여기서는 계절과 `director` 컬럼의 상관 관계에 대해 살펴보자.

# %%
data['season'].value_counts()
# Out:
# Summer    1483
# Autumn    1449
# Spring    1401
# Winter    1363
# Name: season, dtype: int64

# %% [markdown]
# - 우선 데이터셋의 각 계절별 작품 수를 확인해보면 대략 1400개 정도로 제법 골고루 분포한 것을 확인할 수 있다.

# %%
data['director'].nunique()
# Out:
# 4150

# %%
data['director']
# Out:
# 2                     Julien Leclercq
# 5                       Mike Flanagan
# 6       Robert Cullen, José Luis Ucha
# 7                        Haile Gerima
# 8                     Andy Devonshire
#                     ...
# 8801                  Majid Al Ansari
# 8802                    David Fincher
# 8804                  Ruben Fleischer
# 8805                     Peter Hewitt
# 8806                      Mozez Singh
# Name: director, Length: 5696, dtype: object

# %% [markdown]
# - 데이터셋에 포함된 감독의 수는 표면적으로 4150명으로 나타났다.
# - 그러나 실제 데이터를 살펴보면 한 작품에 여러 명의 감독이 쉼표로 구분되어 등재된 경우도 있기 때문에 이는 정확한 수치가 아니다.

# %%
data['director'] = data['director'].apply(lambda x: x.split(",")[0])
data['director']
# Out:
# 2       Julien Leclercq
# 5         Mike Flanagan
# 6         Robert Cullen
# 7          Haile Gerima
# 8       Andy Devonshire
#              ...
# 8801    Majid Al Ansari
# 8802      David Fincher
# 8804    Ruben Fleischer
# 8805       Peter Hewitt
# 8806        Mozez Singh
# Name: director, Length: 5696, dtype: object

# %%
data['director'].nunique()
# Out:
# 4050

# %% [markdown]
# - 여러 감독이 존재할 경우 가장 맨 앞에 등재된 감독을 작품을 대표하는 감독으로 간주했다.
# - 따라서 데이터셋에 포함된 감독의 수는 4050명으로 볼 수 있다.

# %%
dir_freq = data['director'].value_counts()
dir_freq
# Out:
# Rajiv Chilaka      19
# Raúl Campos        18
# Marcus Raboy       16
# Jay Karas          15
# Suhas Kadav        13
#                    ..
# Julien Abraham      1
# Monika Mitchell     1
# Eva Orner           1
# KVR Mahendra        1
# Mozez Singh         1
# Name: director, Length: 4050, dtype: int64

# %%
graph = [go.Bar(
    x=dir_freq.head(20).index,
    y=dir_freq.head(20),
    width=0.5,
    opacity=0.6  # 불투명도
)]

layout = go.Layout(
    autosize=True,
    title='Netflix 데이터셋에서 가장 많은 작품을 한 감독 Top 20',
    hovermode='closest',  # 커서에 가까운 점에 대한 hover 레이블이 나타난다. 
    showlegend=False
)
fig = go.Figure(data=graph, layout=layout)
fig.update_layout(template='plotly_dark')
fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c50bdddb-4cbd-474d-8ad9-d9cdcfb2a857" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c50bdddb-4cbd-474d-8ad9-d9cdcfb2a857")) {                    Plotly.newPlot(                        "c50bdddb-4cbd-474d-8ad9-d9cdcfb2a857",                        [{"opacity":0.6,"width":0.5,"x":["Rajiv Chilaka","Ra\u00fal Campos","Marcus Raboy","Jay Karas","Suhas Kadav","Cathy Garcia-Molina","Youssef Chahine","Jay Chapman","Martin Scorsese","Steven Spielberg","Don Michael Paul","Shannon Hartman","Y\u0131lmaz Erdo\u011fan","David Dhawan","Hakan Alg\u00fcl","Johnnie To","Robert Rodriguez","Kunle Afolayan","Ryan Polito","Lance Bangs"],"y":[19,18,16,15,13,13,12,12,12,11,10,9,9,9,8,8,8,8,8,8],"type":"bar"}],                        {"autosize":true,"hovermode":"closest","showlegend":false,"title":{"text":"Netflix \ub370\uc774\ud130\uc14b\uc5d0\uc11c \uac00\uc7a5 \ub9ce\uc740 \uc791\ud488\uc744 \ud55c \uac10\ub3c5 Top 20"},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogr ...

# %%
dir_freq_spring = data.loc[data['season'] == 'Spring', 'director'].value_counts()
dir_freq_summer = data.loc[data['season'] == 'Summer', 'director'].value_counts()
dir_freq_autumn = data.loc[data['season'] == 'Autumn', 'director'].value_counts()
dir_freq_winter = data.loc[data['season'] == 'Winter', 'director'].value_counts()

# %%
graph = [go.Bar(
    x=dir_freq_spring.head(20).index,
    y=dir_freq_spring.head(20),
    width=0.5,
    marker=dict(
        color=dir_freq_spring.head(20),
        colorscale='Portland',
        reversescale=False  # 색상 스케일이 반전된다.
    ),
    opacity=0.6  # 불투명도
)]

layout = go.Layout(
    autosize=True,
    title='봄에 가장 많은 작품이 등록된 감독 Top 20',
    hovermode='closest',  # 커서에 가까운 점에 대한 hover 레이블이 나타난다. 
    showlegend=False
)
fig = go.Figure(data=graph, layout=layout)
fig.update_layout(template='plotly_dark')
fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="78ae80d3-5b77-46ec-8990-ce4c0771fee5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("78ae80d3-5b77-46ec-8990-ce4c0771fee5")) {                    Plotly.newPlot(                        "78ae80d3-5b77-46ec-8990-ce4c0771fee5",                        [{"marker":{"color":[12,8,6,6,6,6,5,5,5,4,4,4,4,3,3,3,3,3,3,3],"colorscale":[[0.0,"rgb(12,51,131)"],[0.25,"rgb(10,136,186)"],[0.5,"rgb(242,211,56)"],[0.75,"rgb(242,143,56)"],[1.0,"rgb(217,30,30)"]],"reversescale":false},"opacity":0.6,"width":0.5,"x":["Suhas Kadav","Y\u0131lmaz Erdo\u011fan","Fernando Ayll\u00f3n","Hakan Alg\u00fcl","Joey So","Ra\u00fal Campos","Ryan Polito","Marcus Raboy","Hidenori Inoue","Robert Rodriguez","Subhash Ghai","Mike Clattenburg","K\u0131van\u00e7 Baru\u00f6n\u00fc","Wenn V. Deramas","Adriano Rudiman","Mahesh Bhatt","Karan Johar","Hasan Karacada\u011f","Fajar Bustomi","Hanung Bramantyo"],"y":[12,8,6,6,6,6,5,5,5,4,4,4,4,3,3,3,3,3,3,3],"type":"bar"}],                        {"autosize":true,"hovermode":"closest","showlegend":false,"title":{"text":"\ubd04\uc5d0 \uac00\uc7a5 \ub9ce\uc740 \uc791\ud488\uc774 \ub4f1\ub85d\ub41c \uac10\ub3c5 Top 20"},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66666666666 ...

# %%
graph = [go.Bar(
    x=dir_freq_summer.head(20).index,
    y=dir_freq_summer.head(20),
    width=0.5,
    marker=dict(
        color=dir_freq_summer.head(20),
        colorscale='Portland',
        reversescale=False  # 색상 스케일이 반전된다.
    ),
    opacity=0.6  # 불투명도
)]

layout = go.Layout(
    autosize=True,
    title='여름에 가장 많은 작품이 등록된 감독 Top 20',
    hovermode='closest',  # 커서에 가까운 점에 대한 hover 레이블이 나타난다. 
    showlegend=False
)
fig = go.Figure(data=graph, layout=layout)
fig.update_layout(template='plotly_dark')
fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="5213e666-e4f5-4343-ba8d-e65d786f7fc0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5213e666-e4f5-4343-ba8d-e65d786f7fc0")) {                    Plotly.newPlot(                        "5213e666-e4f5-4343-ba8d-e65d786f7fc0",                        [{"marker":{"color":[18,11,6,6,6,5,5,5,5,5,5,4,4,4,4,4,4,4,3,3],"colorscale":[[0.0,"rgb(12,51,131)"],[0.25,"rgb(10,136,186)"],[0.5,"rgb(242,211,56)"],[0.75,"rgb(242,143,56)"],[1.0,"rgb(217,30,30)"]],"reversescale":false},"opacity":0.6,"width":0.5,"x":["Rajiv Chilaka","Youssef Chahine","Jay Chapman","S.S. Rajamouli","Jay Karas","Johnnie To","John G. Avildsen","Martin Scorsese","Marcus Raboy","Ra\u00fal Campos","Thierry Donard","Cristina Jacob","Rathindran R Prasad","Wong Jing","Yoshiyuki Tomino","Chia-Liang Liu","Clay Glen","Khaled Marei","Sameh Abdulaziz","Michael Tiddes"],"y":[18,11,6,6,6,5,5,5,5,5,5,4,4,4,4,4,4,4,3,3],"type":"bar"}],                        {"autosize":true,"hovermode":"closest","showlegend":false,"title":{"text":"\uc5ec\ub984\uc5d0 \uac00\uc7a5 \ub9ce\uc740 \uc791\ud488\uc774 \ub4f1\ub85d\ub41c \uac10\ub3c5 Top 20"},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778 ...

# %%
graph = [go.Bar(
    x=dir_freq_autumn.head(20).index,
    y=dir_freq_autumn.head(20),
    width=0.5,
    marker=dict(
        color=dir_freq_autumn.head(20),
        colorscale='Portland',
        reversescale=False  # 색상 스케일이 반전된다.
    ),
    opacity=0.6  # 불투명도
)]

layout = go.Layout(
    autosize=True,
    title='가을에 가장 많은 작품이 등록된 감독 Top 20',
    hovermode='closest',  # 커서에 가까운 점에 대한 hover 레이블이 나타난다. 
    showlegend=False
)
fig = go.Figure(data=graph, layout=layout)
fig.update_layout(template='plotly_dark')
fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="01a2ebd9-de1f-4603-b93b-bdffbb458550" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01a2ebd9-de1f-4603-b93b-bdffbb458550")) {                    Plotly.newPlot(                        "01a2ebd9-de1f-4603-b93b-bdffbb458550",                        [{"marker":{"color":[7,7,6,6,5,5,5,4,4,4,4,4,4,4,4,4,4,4,3,3],"colorscale":[[0.0,"rgb(12,51,131)"],[0.25,"rgb(10,136,186)"],[0.5,"rgb(242,211,56)"],[0.75,"rgb(242,143,56)"],[1.0,"rgb(217,30,30)"]],"reversescale":false},"opacity":0.6,"width":0.5,"x":["Toshiya Shinohara","Kunle Afolayan","Justin G. Dyck","Noah Baumbach","Cathy Garcia-Molina","Shigeaki Kubo","Riri Riza","David Batty","Oliver Stone","Leslie Small","Troy Miller","Anurag Basu","Masahiko Murata","Banjong Pisanthanakun","Philippe Aractingi","Maroun Baghdadi","Conrad Helten","Raja Gosnell","Ozan A\u00e7\u0131ktan","Robert Vince"],"y":[7,7,6,6,5,5,5,4,4,4,4,4,4,4,4,4,4,4,3,3],"type":"bar"}],                        {"autosize":true,"hovermode":"closest","showlegend":false,"title":{"text":"\uac00\uc744\uc5d0 \uac00\uc7a5 \ub9ce\uc740 \uc791\ud488\uc774 \ub4f1\ub85d\ub41c \uac10\ub3c5 Top 20"},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.777 ...

# %%
graph = [go.Bar(
    x=dir_freq_winter.head(20).index,
    y=dir_freq_winter.head(20),
    width=0.5,
    marker=dict(
        color=dir_freq_winter.head(20),
        colorscale='Portland',
        reversescale=False  # 색상 스케일이 반전된다.
    ),
    opacity=0.6  # 불투명도
)]

layout = go.Layout(
    autosize=True,
    title='겨울에 가장 많은 작품이 등록된 감독 Top 20',
    hovermode='closest',  # 커서에 가까운 점에 대한 hover 레이블이 나타난다. 
    showlegend=False
)
fig = go.Figure(data=graph, layout=layout)
fig.update_layout(template='plotly_dark')
fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d1a656bb-681f-4e7e-8cbd-3390562db2f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d1a656bb-681f-4e7e-8cbd-3390562db2f1")) {                    Plotly.newPlot(                        "d1a656bb-681f-4e7e-8cbd-3390562db2f1",                        [{"marker":{"color":[7,6,5,4,4,4,4,4,4,4,4,4,4,4,4,3,3,3,3,3],"colorscale":[[0.0,"rgb(12,51,131)"],[0.25,"rgb(10,136,186)"],[0.5,"rgb(242,211,56)"],[0.75,"rgb(242,143,56)"],[1.0,"rgb(217,30,30)"]],"reversescale":false},"opacity":0.6,"width":0.5,"x":["Cathy Garcia-Molina","Ra\u00fal Campos","Steven Spielberg","Sooraj R. Barjatya","Hrishikesh Mukherjee","David Dhawan","Marcus Raboy","Matt Askem","Jay Karas","Jay Chapman","Lance Bangs","Farhan Akhtar","Omoni Oboli","Ron Howard","Hanung Bramantyo","Don Michael Paul","Quentin Tarantino","Wenn V. Deramas","Yasmin Ahmad","Mark A.Z. Dipp\u00e9"],"y":[7,6,5,4,4,4,4,4,4,4,4,4,4,4,4,3,3,3,3,3],"type":"bar"}],                        {"autosize":true,"hovermode":"closest","showlegend":false,"title":{"text":"\uaca8\uc6b8\uc5d0 \uac00\uc7a5 \ub9ce\uc740 \uc791\ud488\uc774 \ub4f1\ub85d\ub41c \uac10\ub3c5 Top 20"},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.777 ...

# %% [markdown]
# - 각 계절별 가장 많은 작품이 등록된 감독 Top 20을 살펴보았다.
# - 생각보다 특정 계절에 여러 작품이 등록된 감독이 많은 것으로 보인다.

# %%
data['season'].unique()
# Out:
# array(['Autumn', 'Summer', 'Spring', 'Winter'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(data['season'])
data['encoded_season'] = le.transform(data['season'])
le.fit(data['director'])
data['encoded_director'] = le.transform(data['director'])
data.head()
# Out:
#   show_id     type                             title         director  \
# 2      s3  TV Show                         Ganglands  Julien Leclercq
# 5      s6  TV Show                     Midnight Mass    Mike Flanagan
# 6      s7    Movie  My Little Pony: A New Generation    Robert Cullen
# 7      s8    Movie                           Sankofa     Haile Gerima
# 8      s9  TV Show     The Great British Baking Show  Andy Devonshire
#
#                                              country  release_year rating  \
# 2                                      United States          2021  TV-MA
# 5                                      United States          2021  TV-MA
# 6                                      United States          2021     PG
# 7  United States, Ghana, Burkina Faso, United Kin...          1993  TV-MA
# 8                                     United Kingdom          2021  TV-14
#
#     duration                                          listed_in  season  \
# 2   1 Season  Crime TV Shows, International TV Shows, TV Act...  Autumn
# 5   1 Season                 TV Dramas, TV Horror, TV Mysteries  Autumn
# 6     91 min                           Children & Family Movies  Autumn
# 7    125 min   Dramas, Independent Movies, International Movies  Autumn
# 8  9 Seasons                       British TV Shows, Reality TV  Autumn
#
#    encoded_season  encoded_director
# 2               0              1867
# 5               0              2541
# 6               0              3166
# 7               0              1339
# 8               0               263

# %% [markdown]
# - `season` 컬럼과 `director` 컬럼의 상관관계를 확인하기 위해 각 컬럼을 라벨 인코딩했다.
# - 추가로, 작품의 장르를 의미하는 `listed_in` 컬럼과 감독, 계절의 상관관계도 궁금해서 확인해보기로 했다.
# - 장르의 경우 감독명처럼 하나의 작품이 다수의 장르에 속하는 경우가 대부분이기에 맨 앞 장르를 대표 장르로 간주했다.

# %%
data['listed_in'] = data['listed_in'].apply(lambda x: x.split(",")[0])
le.fit(data['listed_in'])
data['encoded_listed_in'] = le.transform(data['listed_in'])
data.head()
# Out:
#   show_id     type                             title         director  \
# 2      s3  TV Show                         Ganglands  Julien Leclercq
# 5      s6  TV Show                     Midnight Mass    Mike Flanagan
# 6      s7    Movie  My Little Pony: A New Generation    Robert Cullen
# 7      s8    Movie                           Sankofa     Haile Gerima
# 8      s9  TV Show     The Great British Baking Show  Andy Devonshire
#
#                                              country  release_year rating  \
# 2                                      United States          2021  TV-MA
# 5                                      United States          2021  TV-MA
# 6                                      United States          2021     PG
# 7  United States, Ghana, Burkina Faso, United Kin...          1993  TV-MA
# 8                                     United Kingdom          2021  TV-14
#
#     duration                 listed_in  season  encoded_season  \
# 2   1 Season            Crime TV Shows  Autumn               0
# 5   1 Season                 TV Dramas  Autumn               0
# 6     91 min  Children & Family Movies  Autumn               0
# 7    125 min                    Dramas  Autumn               0
# 8  9 Seasons          British TV Shows  Autumn               0
#
#    encoded_director  encoded_listed_in
# 2              1867                  8
# 5              2541                 29
# 6              3166                  4
# 7              1339                 12
# 8               263                  3

# %%
colormap = plt.cm.RdBu
plt.style.use(['dark_background'])
plt.figure(figsize=(14, 12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(data[['encoded_season', 'encoded_director', 'encoded_listed_in']].astype(float).corr(), linewidth=0.1,  # linewidth : 히트맵 블록 사이 경계선
            vmax=1.0, square=True, cmap=colormap,  # vmax : 색으로 표현하는 최대값, square : 차트를 정사각형으로 할 것인지
            linecolor='black', annot=True)  # annot : 블록의 숫자 표시

# %% [markdown]
# - Heatmap을 그려보니 생각보다 계절과 감독과의 상관도가 많이 낮게 나왔다... 음...
# - 아마 현재 계절을 나눈 것이 우리나라의 계절을 기준으로 나눴고, 넷플릭스 데이터셋은 전 세계의 데이터셋이다 보니 각 국가별 계절이 달라서 상관관계가 낮게 나온건가 하는 생각이 든다.
# - 국가별로 분리해서 다시 계절별로 살펴볼 필요가 있을 것 같다.
# - 장르의 경우 한 작품이 여러 장르에 속하는데 맨 앞의 장르를 대표 장르로 설정하는 과정에서 한 작품에 대한 장르의 특성이 많이 희석된 것으로 보인다. 이는 한 작품이 속하는 모든 장르를 다 고려할 수 있도록 새롭게 분석해봐야할 것 같다.

# %%
country_freq = data['country'].value_counts()
country_freq.head(10)
# Out:
# United States     2210
# India              875
# United Kingdom     183
# Canada             107
# Spain               91
# Egypt               90
# Nigeria             88
# Japan               83
# Turkey              79
# Indonesia           76
# Name: country, dtype: int64

# %%
graph = [go.Bar(
    x=country_freq.head(10).index,
    y=country_freq.head(10),
    width=0.5,
    marker=dict(
        color=dir_freq_winter.head(20),
        colorscale='Portland',
        reversescale=False  # 색상 스케일이 반전된다.
    ),
    opacity=0.6  # 불투명도
)]

layout = go.Layout(
    autosize=True,
    title='가장 많은 작품이 속한 국가 Top 10',
    hovermode='closest',  # 커서에 가까운 점에 대한 hover 레이블이 나타난다. 
    showlegend=False
)
fig = go.Figure(data=graph, layout=layout)
fig.update_layout(template='plotly_dark')
fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="18c60ea9-5c9a-4a54-8bc7-f8d9b0301cf1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("18c60ea9-5c9a-4a54-8bc7-f8d9b0301cf1")) {                    Plotly.newPlot(                        "18c60ea9-5c9a-4a54-8bc7-f8d9b0301cf1",                        [{"marker":{"color":[7,6,5,4,4,4,4,4,4,4,4,4,4,4,4,3,3,3,3,3],"colorscale":[[0.0,"rgb(12,51,131)"],[0.25,"rgb(10,136,186)"],[0.5,"rgb(242,211,56)"],[0.75,"rgb(242,143,56)"],[1.0,"rgb(217,30,30)"]],"reversescale":false},"opacity":0.6,"width":0.5,"x":["United States","India","United Kingdom","Canada","Spain","Egypt","Nigeria","Japan","Turkey","Indonesia"],"y":[2210,875,183,107,91,90,88,83,79,76],"type":"bar"}],                        {"autosize":true,"hovermode":"closest","showlegend":false,"title":{"text":"\uac00\uc7a5 \ub9ce\uc740 \uc791\ud488\uc774 \uc18d\ud55c \uad6d\uac00 Top 10"},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}] ...

# %% [markdown]
# - 가장 많은 작품이 속한 국가를 살펴보니 미국이 2210개로 압도적이었고, 그 뒤로 인도, 영국 등의 순서였다.
# - 미국의 경우 계절이 우리나라와 유사하기에 처음에 `season` 컬럼을 만든 기준에는 부합하는 것 같다.
# - 각 계절별로 여러 작품을 냈던 감독들의 국가를 확인해봐야겠다.

# %% [markdown]
# ### 봄에 가장 많은 작품이 등록된 감독들 살펴보기

# %%
data.loc[(data['director'] == 'Suhas Kadav') & (data['season'] == 'Spring'), 'listed_in'].value_counts()
# Out:
# Children & Family Movies    12
# Name: listed_in, dtype: int64

#
#             director country  release_year rating duration  \
# 906   Yılmaz Erdoğan  Turkey          1999  TV-MA  118 min
# 995   Yılmaz Erdoğan  Turkey          2001  TV-MA  106 min
# 2605  Yılmaz Erdoğan  Turkey          2016  TV-PG  109 min
# 2620  Yılmaz Erdoğan  Turkey          2009  TV-14  108 min
# 2621  Yılmaz Erdoğan  Turkey          2005  TV-14  104 min
# 3402  Yılmaz Erdoğan  Turkey          2017  TV-14   95 min
# 3889  Yılmaz Erdoğan  Turkey          2019  TV-MA  122 min
# 5581  Yılmaz Erdoğan  Turkey          2013  TV-PG  118 min
# 8682  Yılmaz Erdoğan  Turkey          2004     NR  106 min
#
#                listed_in  season  encoded_season  encoded_director  \
# 906               Dramas  Spring               1              4016
# 995             Comedies  Spring               1              4016
# 2605              Dramas  Spring               1              4016
# 2620            Comedies  Spring               1              4016
# 2621  Action & Adventure  Spring               1              4016
# 3402            Comedies  Autumn               0              4016
# 3889            Comedies  Spring               1              4016
# 5581              Dramas  Spring               1              4016
# 8682            Comedies  Spring               1              4016
#
#       encoded_listed_in
# 906                  12
# 995                   7
# 2605                 12
# 2620                  7
# 2621                  0
# 3402                  7
# 3889                  7
# 5581                 12
# 8682                  7

# %%
data[data['director'] == 'Fernando Ayllón']
# Out:
#      show_id   type                                       title  \
# 1164   s1165  Movie                                  Ni de coña
# 2567   s2568  Movie                              Death Can Wait
# 3138   s3139  Movie                           Holy Expectations
# 3548   s3549  Movie                            Feo pero sabroso
# 3888   s3889  Movie                            Loving is Losing
# 3929   s3930  Movie           Liss Pereira: Reteniendo líquidos
# 3947   s3948  Movie    Ricardo Quevedo: Los amargados somos más
# 4883   s4884  Movie  Si saben cómo me pongo ¿pá qué me invitan?
#
#              director        country  release_year rating duration  \
# 1164  Fernando Ayllón          Spain          2020  TV-MA   97 min
# 2567  Fernando Ayllón       Colombia          2020  TV-14   91 min
# 3138  Fernando Ayllón  United States          2019  TV-14   89 min
# 3548  Fernando Ayllón       Colombia          2018  TV-MA   91 min
# 3888  Fernando Ayllón       Colombia          2019  TV-MA   91 min
# 3929  Fernando Ayllón         Brazil          2019  TV-14   59 min
# 3947  Fernando Ayllón  United States          2019  TV-MA   59 min
# 4883  Fernando Ayllón       Colombia          2018  TV-MA   89 min
#
#                      listed_in  season  encoded_season  encoded_director  \
# 1164                  Comedies  Spring               1              1140
# 2567                  Comedies  Spring               1              1140
# 3138  Children & Family Movies  Winter               3              1140
# 3548                  Comedies  Summer               2              1140
# 3888                  Comedies  Spring               1              1140
# 3929           Stand-Up Comedy  Spring               1              1140
# 3947           Stand-Up Comedy  Spring               1              1140
# 4883                  Comedies  Spring               1              1140
#
#       encoded_listed_in
# 1164                  7
# 2567                  7
# 3138                  4
# 3548                  7
# 3888                  7
# 3929                 25
# 3947                 25
# 4883                  7

# %%
graph = [go.Pie(
    labels=data.loc[((data['director'] == 'Fernando Ayllón') | (data['director'] == 'Suhas Kadav') | (data['director'] == 'Yılmaz Erdoğan')) & (data['season'] == 'Spring'), 'listed_in'].value_counts().index,
    values=data.loc[((data['director'] == 'Fernando Ayllón') | (data['director'] == 'Suhas Kadav') | (data['director'] == 'Yılmaz Erdoğan')) & (data['season'] == 'Spring'), 'listed_in'].value_counts(),
    hole=.3
)]

layout = go.Layout(
    autosize=True,
    title='봄에 가장 많은 작품이 등록된 Top 3 감독들의 작품 장르',
    hovermode='closest',  # 커서에 가까운 점에 대한 hover 레이블이 나타난다. 
    showlegend=True
)
fig = go.Figure(data=graph, layout=layout)
fig.update_layout(template='plotly_dark')
fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e6ba0e30-6269-4220-814f-20cbb2e644f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e6ba0e30-6269-4220-814f-20cbb2e644f8")) {                    Plotly.newPlot(                        "e6ba0e30-6269-4220-814f-20cbb2e644f8",                        [{"hole":0.3,"labels":["Children & Family Movies","Comedies","Dramas","Stand-Up Comedy","Action & Adventure"],"values":[12,8,3,2,1],"type":"pie"}],                        {"autosize":true,"hovermode":"closest","showlegend":true,"title":{"text":"\ubd04\uc5d0 \uac00\uc7a5 \ub9ce\uc740 \uc791\ud488\uc774 \ub4f1\ub85d\ub41c Top 3 \uac10\ub3c5\ub4e4\uc758 \uc791\ud488 \uc7a5\ub974"},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar ...

# %%
graph = [go.Pie(
    labels=data.loc[((data['director'] == 'Fernando Ayllón') | (data['director'] == 'Suhas Kadav') | (data['director'] == 'Yılmaz Erdoğan')) & (data['season'] == 'Spring'), 'rating'].value_counts().index,
    values=data.loc[((data['director'] == 'Fernando Ayllón') | (data['director'] == 'Suhas Kadav') | (data['director'] == 'Yılmaz Erdoğan')) & (data['season'] == 'Spring'), 'rating'].value_counts(),
    hole=.3
)]

layout = go.Layout(
    autosize=True,
    title='봄에 가장 많은 작품이 등록된 Top 3 감독들의 작품 등급',
    hovermode='closest',  # 커서에 가까운 점에 대한 hover 레이블이 나타난다. 
    showlegend=True
)
fig = go.Figure(data=graph, layout=layout)
fig.update_layout(template='plotly_dark')
fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="bf418ccd-d2be-4392-ab30-e2948c4440f4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bf418ccd-d2be-4392-ab30-e2948c4440f4")) {                    Plotly.newPlot(                        "bf418ccd-d2be-4392-ab30-e2948c4440f4",                        [{"hole":0.3,"labels":["TV-Y7","TV-MA","TV-14","TV-Y","TV-PG","NR"],"values":[10,7,4,2,2,1],"type":"pie"}],                        {"autosize":true,"hovermode":"closest","showlegend":true,"title":{"text":"\ubd04\uc5d0 \uac00\uc7a5 \ub9ce\uc740 \uc791\ud488\uc774 \ub4f1\ub85d\ub41c Top 3 \uac10\ub3c5\ub4e4\uc758 \uc791\ud488 \ub4f1\uae09"},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type": ...

# %% [markdown]
# - 봄에 가장 많은 작품이 등록된 감독 3명에 대해 살펴보았다.
# - 12개의 작품이 등록된 Suhas Kadav의 경우, 작품의 모든 장르가 어린이 및 가족 영화였다.
# - Heatmap에서 상관계수는 낮게 나왔더라도 어느 정도 특정 감독이 특정 장르 위주로 작품을 내는 것 같다.
# - 8개의 작품이 등록된 Yılmaz Erdoğan의 경우, 대부분의 장르가 드라마와 코미디 영화였다.
# - 6개의 작품이 등록된 감독은 많았는데, 그 중 Fernando Ayllón의 경우, 대부분의 작품이 코미디, 어린이 및 가족 영화였다.
# 4248   s4249  Movie   Todd Glass: Stand-Up Special  Jay Chapman
# 5108   s5109  Movie        Todd Barry: Spicy Honey  Jay Chapman
# 5134   s5135  Movie   Craig Ferguson: Tickle Fight  Jay Chapman
# 5325   s5326  Movie    Brad Paisley's Comedy Rodeo  Jay Chapman
# 5326   s5327  Movie  Colin Quinn: Unconstitutional  Jay Chapman
# 5378   s5379  Movie            D.L. Hughley: Clear  Jay Chapman
# 5379   s5380  Movie  Tom Segura: Completely Normal  Jay Chapman
# 5525   s5526  Movie       Lucas Brothers: On Drugs  Jay Chapman
# 5818   s5819  Movie         Jim Gaffigan: Obsessed  Jay Chapman
# 7056   s7057  Movie    Iliza Shlesinger: War Paint  Jay Chapman
#
#             country  release_year rating duration         listed_in  season  \
# 3645  United States          2018  TV-MA   58 min   Stand-Up Comedy  Summer
# 4222  United States          2012  TV-MA   61 min   Stand-Up Comedy  Winter
# 4248  United States          2012  TV-MA   46 min   Stand-Up Comedy  Winter
# 5108  United States          2017  TV-MA   61 min   Stand-Up Comedy  Winter
# 5134  United States          2017  TV-MA   67 min   Stand-Up Comedy  Winter
# 5325  United States          2017  TV-MA   63 min  Music & Musicals  Summer
# 5326  United States          2015  TV-MA   56 min   Stand-Up Comedy  Summer
# 5378  United States          2014  TV-MA   59 min   Stand-Up Comedy  Summer
# 5379  United States          2014  TV-MA   74 min   Stand-Up Comedy  Summer
# 5525  United States          2017  TV-MA   50 min   Stand-Up Comedy  Spring
# 5818  United States          2014  TV-14   70 min   Stand-Up Comedy  Summer
# 7056  United States          2013     NR   75 min   Stand-Up Comedy  Autumn
#
#       encoded_season  encoded_director  encoded_listed_in
# 3645               2              1592                 25
# 4222               3              1592                 25
# 4248               3              1592                 25
# 5108               3              1592                 25
# 5134               3              1592                 25
# 5325               2              1592                 20
# 5326               2              1592                 25
# 5378               2              1592                 25
# 5379               2              1592                 25
# 5525               1              1592                 25
# 5818               2              1592                 25
# 7056               0              1592                 25

# %%
graph = [go.Pie(
    labels=data.loc[((data['director'] == 'Rajiv Chilaka') | (data['director'] == 'Youssef Chahine') | (data['director'] == 'Jay Chapman')) & (data['season'] == 'Summer'), 'listed_in'].value_counts().index,
    values=data.loc[((data['director'] == 'Rajiv Chilaka') | (data['director'] == 'Youssef Chahine') | (data['director'] == 'Jay Chapman')) & (data['season'] == 'Summer'), 'listed_in'].value_counts(),
    hole=.3
)]

layout = go.Layout(
    autosize=True,
    title='여름에 가장 많은 작품이 등록된 Top 3 감독들의 작품 장르',
    hovermode='closest',  # 커서에 가까운 점에 대한 hover 레이블이 나타난다. 
    showlegend=True
)
fig = go.Figure(data=graph, layout=layout)
fig.update_layout(template='plotly_dark')
fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="707577f3-6009-4c64-9dd0-1dc1904f158e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("707577f3-6009-4c64-9dd0-1dc1904f158e")) {                    Plotly.newPlot(                        "707577f3-6009-4c64-9dd0-1dc1904f158e",                        [{"hole":0.3,"labels":["Children & Family Movies","Classic Movies","Stand-Up Comedy","Dramas","Action & Adventure","Music & Musicals"],"values":[18,7,5,3,1,1],"type":"pie"}],                        {"autosize":true,"hovermode":"closest","showlegend":true,"title":{"text":"\uc5ec\ub984\uc5d0 \uac00\uc7a5 \ub9ce\uc740 \uc791\ud488\uc774 \ub4f1\ub85d\ub41c Top 3 \uac10\ub3c5\ub4e4\uc758 \uc791\ud488 \uc7a5\ub974"},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0 ...

# %%
graph = [go.Pie(
    labels=data.loc[((data['director'] == 'Rajiv Chilaka') | (data['director'] == 'Youssef Chahine') | (data['director'] == 'Jay Chapman')) & (data['season'] == 'Summer'), 'rating'].value_counts().index,
    values=data.loc[((data['director'] == 'Rajiv Chilaka') | (data['director'] == 'Youssef Chahine') | (data['director'] == 'Jay Chapman')) & (data['season'] == 'Summer'), 'rating'].value_counts(),
    hole=.3
)]

layout = go.Layout(
    autosize=True,
    title='여름에 가장 많은 작품이 등록된 Top 3 감독들의 작품 등급',
    hovermode='closest',  # 커서에 가까운 점에 대한 hover 레이블이 나타난다. 
    showlegend=True
)
fig = go.Figure(data=graph, layout=layout)
fig.update_layout(template='plotly_dark')
fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4bd15881-ea79-4247-945d-70a04c593028" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4bd15881-ea79-4247-945d-70a04c593028")) {                    Plotly.newPlot(                        "4bd15881-ea79-4247-945d-70a04c593028",                        [{"hole":0.3,"labels":["TV-Y7","TV-MA","TV-14"],"values":[18,11,6],"type":"pie"}],                        {"autosize":true,"hovermode":"closest","showlegend":true,"title":{"text":"\uc5ec\ub984\uc5d0 \uac00\uc7a5 \ub9ce\uc740 \uc791\ud488\uc774 \ub4f1\ub85d\ub41c Top 3 \uac10\ub3c5\ub4e4\uc758 \uc791\ud488 \ub4f1\uae09"},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scat ...

# %% [markdown]
# - 여름에 가장 많은 작품이 등록된 감독들을 살펴보면, 무려 18개의 작품이 등록된 Rajiv Chilaka의 모든 작품은 어린이 및 가족 영화였고, 국가는 미국이었다.
# - 11개의 작품이 등록된 Youssef Chahine은, 클래식 영화나 드라마가 주된 장르였고, 국가는 이집트였다.
# - 6개의 작품이 등록된 감독은 많았지만, 그 중 Jay Chapman의 경우 스탠드업 코미디가 주된 장르이고, 국가는 미국이었다.
# - 사실 우리나라의 예로써 직관적으로 추측했을 때, 여름에 액션이나 호러 장르의 작품이 많을 것이라 예상했는데 그것은 아닌 것 같다.
# - 참고로 이집트의 덥고 건조한 사막기후이지만 계절 흐름은 우리나라와 비슷하다고 한다.

# %% [markdown]
# ### 가을에 가장 많은 작품이 등록된 감독들 살펴보기

# %%
data[data['director'] == 'Toshiya Shinohara']
# Out:
#      show_id   type                                              title  \
# 51       s52  Movie  InuYasha the Movie 2: The Castle Beyond the Lo...
# 52       s53  Movie  InuYasha the Movie 3: Swords of an Honorable R...
# 53       s54  Movie    InuYasha the Movie 4: Fire on the Mystic Island
# 54       s55  Movie  InuYasha the Movie: Affections Touching Across...
# 7088   s7089  Movie   Inuyasha the Movie - L'isola del fuoco scarlatto
# 7089   s7090  Movie  Inuyasha the Movie - La spada del dominatore d...
# 7090   s7091  Movie  InuYasha: The Movie 2: The Castle Beyond the L...
#
#                director country  release_year rating duration  \
# 51    Toshiya Shinohara   Japan          2002  TV-14   99 min
# 4891                 Canada          2018     PG   92 min
#
#                      listed_in  season  encoded_season  encoded_director  \
# 1691          Music & Musicals  Autumn               0              1894
# 1695           Romantic Movies  Autumn               0              1894
# 1739                  Comedies  Autumn               0              1894
# 4390                  Comedies  Autumn               0              1894
# 4428      International Movies  Autumn               0              1894
# 4557  Children & Family Movies  Autumn               0              1894
# 4891                  Comedies  Spring               1              1894
#
#       encoded_listed_in
# 1691                 20
# 1695                 22
# 1739                  7
# 4390                  7
# 4428                 15
# 4557                  4
# 4891                  7

# %%
graph = [go.Pie(
    labels=data.loc[((data['director'] == 'Toshiya Shinohara') | (data['director'] == 'Kunle Afolayan') | (data['director'] == 'Justin G. Dyck')) & (data['season'] == 'Autumn'), 'listed_in'].value_counts().index,
    values=data.loc[((data['director'] == 'Toshiya Shinohara') | (data['director'] == 'Kunle Afolayan') | (data['director'] == 'Justin G. Dyck')) & (data['season'] == 'Autumn'), 'listed_in'].value_counts(),
    hole=.3
)]

layout = go.Layout(
    autosize=True,
    title='가을에 가장 많은 작품이 등록된 Top 3 감독들의 작품 장르',
    hovermode='closest',  # 커서에 가까운 점에 대한 hover 레이블이 나타난다. 
    showlegend=True
)
fig = go.Figure(data=graph, layout=layout)
fig.update_layout(template='plotly_dark')
fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e093068c-69b8-47de-8022-08427b12c74d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e093068c-69b8-47de-8022-08427b12c74d")) {                    Plotly.newPlot(                        "e093068c-69b8-47de-8022-08427b12c74d",                        [{"hole":0.3,"labels":["Action & Adventure","Dramas","Comedies","Music & Musicals","Romantic Movies","International Movies","Children & Family Movies","Horror Movies"],"values":[7,5,3,1,1,1,1,1],"type":"pie"}],                        {"autosize":true,"hovermode":"closest","showlegend":true,"title":{"text":"\uac00\uc744\uc5d0 \uac00\uc7a5 \ub9ce\uc740 \uc791\ud488\uc774 \ub4f1\ub85d\ub41c Top 3 \uac10\ub3c5\ub4e4\uc758 \uc791\ud488 \uc7a5\ub974"},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{ ...

# %%
graph = [go.Pie(
    labels=data.loc[((data['director'] == 'Toshiya Shinohara') | (data['director'] == 'Kunle Afolayan') | (data['director'] == 'Justin G. Dyck')) & (data['season'] == 'Autumn'), 'rating'].value_counts().index,
    values=data.loc[((data['director'] == 'Toshiya Shinohara') | (data['director'] == 'Kunle Afolayan') | (data['director'] == 'Justin G. Dyck')) & (data['season'] == 'Autumn'), 'rating'].value_counts(),
    hole=.3
)]

layout = go.Layout(
    autosize=True,
    title='가을에 가장 많은 작품이 등록된 Top 3 감독들의 작품 등급',
    hovermode='closest',  # 커서에 가까운 점에 대한 hover 레이블이 나타난다. 
    showlegend=True
)
fig = go.Figure(data=graph, layout=layout)
fig.update_layout(template='plotly_dark')
fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="06196caa-fa7c-4055-9539-aac68da001bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("06196caa-fa7c-4055-9539-aac68da001bd")) {                    Plotly.newPlot(                        "06196caa-fa7c-4055-9539-aac68da001bd",                        [{"hole":0.3,"labels":["TV-14","TV-PG","TV-G","PG","TV-MA"],"values":[10,5,2,2,1],"type":"pie"}],                        {"autosize":true,"hovermode":"closest","showlegend":true,"title":{"text":"\uac00\uc744\uc5d0 \uac00\uc7a5 \ub9ce\uc740 \uc791\ud488\uc774 \ub4f1\ub85d\ub41c Top 3 \uac10\ub3c5\ub4e4\uc758 \uc791\ud488 \ub4f1\uae09"},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"
# 4962               1              3073                 25
# 5001               1              3073                 25
# 5002               1              3073                 25
# 5062               3              3073                 25
# 5066               3              3073                 25
# 5076               3              3073                 25
# 5176               0              3073                 25
# 5342               2              3073                 25
# 5614               3              3073                 25
# 5678               3              3073                 25
# 5839               2              3073                 25
# 5872               3              3073                 25

# %%
data[data['director'] == 'Steven Spielberg']
# Out:
#      show_id   type                                              title  \
# 41       s42  Movie                                               Jaws
# 329     s330  Movie                                Catch Me If You Can
# 1203   s1204  Movie                                            The BFG
# 7070   s7071  Movie  Indiana Jones and the Kingdom of the Crystal S...
# 7071   s7072  Movie                 Indiana Jones and the Last Crusade
# 7072   s7073  Movie      Indiana Jones and the Raiders of the Lost Ark
# 7073   s7074  Movie               Indiana Jones and the Temple of Doom
# 7308   s7309  Movie                                            Lincoln
# 7957   s7958  Movie                                   Schindler's List
# 8184   s8185  Movie                           The Adventures of Tintin
# 8696   s8697  Movie                                          War Horse
#
#               director                                     country  \
# 41    Steven Spielberg                               United States
# 329   Steven Spielberg                       United States, Canada
# 1203  Steven Spielberg        United States, India, United Kingdom
# 7070  Steven Spielberg                               United States
# 7071  Steven Spielberg                               United States
# 7072  Steven Spielberg                               United States
# 7073  Steven Spielberg                               United States
# 7308  Steven Spielberg                        United States, India
# 7957  Steven Spielberg                               United States
# 8184  Steven Spielberg  United States, New Zealand, United Kingdom
# 8696  Steven Spielberg                        United States, India
#
#       release_year rating duration                 listed_in  season  \
# 41            1975     PG  124 min        Action & Adventure  Autumn
# 329           2002  PG-13  142 min                    Dramas  Summer
# 1203          2016     PG  118 min  Children & Family Movies  Spring
# 7070          2008  PG-13  123 min        Action & Adventure  Winter
# 7071          1989  PG-13  127 min        Action & Adventure  Winter
# 7072          1981     PG  116 min        Action & Adventure  Winter
# 7073          1984     PG  119 min        Action & Adventure  Winter
# 7308          2012  PG-13  150 min                    Dramas  Winter
# 7957          1993      R  195 min            Classic Movies  Spring
# 8184          2011     PG  107 min  Children & Family Movies  Autumn
# 8696          2011  PG-13  147 min                    Dramas  Spring
#
#       encoded_season  encoded_director  encoded_listed_in
# 41                 0              3594                  0
# 329                2              3594                 12
# 1203               1              3594                  4
# 7070               3              3594                  0
# 7071               3              3594                  0
# 7072               3              3594                  0
# 7073               3              3594                  0
# 7308               3              3594                 12
# 7957               1              3594                  6
# 8184               0              3594                  4
# 8696               1              3594                 12

# %%
graph = [go.Pie(
    labels=data.loc[((data['director'] == 'Cathy Garcia-Molina') | (data['director'] == 'Raúl Campos') | (data['director'] == 'Steven Spielberg')) & (data['season'] == 'Winter'), 'listed_in'].value_counts().index,
    values=data.loc[((data['director'] == 'Cathy Garcia-Molina') | (data['director'] == 'Raúl Campos') | (data['director'] == 'Steven Spielberg')) & (data['season'] == 'Winter'), 'listed_in'].value_counts(),
    hole=.3
)]

layout = go.Layout(
    autosize=True,
    title='겨울에 가장 많은 작품이 등록된 Top 3 감독들의 작품 장르',
    hovermode='closest',  # 커서에 가까운 점에 대한 hover 레이블이 나타난다. 
    showlegend=True
)
fig = go.Figure(data=graph, layout=layout)
fig.update_layout(template='plotly_dark')
fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="442fa541-9213-4c20-b4ef-782df6c3e06b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("442fa541-9213-4c20-b4ef-782df6c3e06b")) {                    Plotly.newPlot(                        "442fa541-9213-4c20-b4ef-782df6c3e06b",                        [{"hole":0.3,"labels":["Stand-Up Comedy","Dramas","Comedies","Action & Adventure"],"values":[6,4,4,4],"type":"pie"}],                        {"autosize":true,"hovermode":"closest","showlegend":true,"title":{"text":"\uaca8\uc6b8\uc5d0 \uac00\uc7a5 \ub9ce\uc740 \uc791\ud488\uc774 \ub4f1\ub85d\ub41c Top 3 \uac10\ub3c5\ub4e4\uc758 \uc791\ud488 \uc7a5\ub974"},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"tic ...

# %%
graph = [go.Pie(
    labels=data.loc[((data['director'] == 'Cathy Garcia-Molina') | (data['director'] == 'Raúl Campos') | (data['director'] == 'Steven Spielberg')) & (data['season'] == 'Winter'), 'rating'].value_counts().index,
    values=data.loc[((data['director'] == 'Cathy Garcia-Molina') | (data['director'] == 'Raúl Campos') | (data['director'] == 'Steven Spielberg')) & (data['season'] == 'Winter'), 'rating'].value_counts(),
    hole=.3
)]

layout = go.Layout(
    autosize=True,
    title='겨울에 가장 많은 작품이 등록된 Top 3 감독들의 작품 등급',
    hovermode='closest',  # 커서에 가까운 점에 대한 hover 레이블이 나타난다. 
    showlegend=True
)
fig = go.Figure(data=graph, layout=layout)
fig.update_layout(template='plotly_dark')
fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b951bcb0-177e-415a-b2aa-937ea8e07ac6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b951bcb0-177e-415a-b2aa-937ea8e07ac6")) {                    Plotly.newPlot(                        "b951bcb0-177e-415a-b2aa-937ea8e07ac6",                        [{"hole":0.3,"labels":["TV-MA","TV-14","PG-13","TV-PG","PG"],"values":[7,4,3,2,2],"type":"pie"}],                        {"autosize":true,"hovermode":"closest","showlegend":true,"title":{"text":"\uaca8\uc6b8\uc5d0 \uac00\uc7a5 \ub9ce\uc740 \uc791\ud488\uc774 \ub4f1\ub85d\ub41c Top 3 \uac10\ub3c5\ub4e4\uc758 \uc791\ud488 \ub4f1\uae09"},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"sca ...

# %% [markdown]
# - 겨울에 7개의 작품이 등록된 Cathy Garcia-Molina의 국가는 필리핀으로, 주로 코미디와 드라마 장르의 영화 작품이 등록되었다.
# - 6개의 작품이 등록된 Raúl Campos의 경우 겨울에 등록된 작품들의 장르는 모두 스탠드업 코미디 영화였고, 국가는 남미의 여러 국가들이었다.
# - 겨울에 5개의 작품이 등록된 Steven Spielberg의 경우 겨울에 등록된 작품은 모두 액션 및 어드벤처 장르(인디아나 존스 시리즈)의 영화임을 알 수 있다.
# - 계절별로 분석해봤을 때 각각 가장 많은 작품이 등록된 3명의 감독에 대한 작품만 살펴봤기에 단편적일 수도 있겠지만, 어느정도 특정 계절에 많이 등록된 감독들의 주된 장르가 대체로 일치하지는 않았다.
# - 이는 장르 컬럼을 맨 앞의 장르를 대표 장르로 사용하도록 데이터를 정제하는 과정에서 일부 특성이 희석됐을 수도 있고, 국가별 계절의 양상이 비슷하더라도 정치적, 문화적 요인 등 다양한 외부 요인으로 인해 계절별 작품에 대한 선호도를 명확하게 알기 힘들기 때문으로 보인다.
